# %% [markdown]
# # S & P 500 Stock Prices

# %% [markdown]
# ## Introduction
# Stock Market is a place where shares of pubic listed companies are traded. The primary market is where companies float shares to the general public in an initial public offering (IPO) to raise capital (The Economic Times, 2023).
#
#    In this analysis, I will be answering few questions on historical stock market data for current S&P 500 companies, from **2014-2017**. Each record represents a single day of trading, and includes the ticker name, volume, high, low, open and close prices.

# %% [markdown]
# ## Data Validation
# Before I procceded with my analysis, I ensured I perfomed thorough data validation and data wrangling to the dataset that was provided to me, my results are well explained below:
#
# The original data consist of 497472 rows and 7 columns, namely; 'symbol', 'date', 'open', 'high', 'low', 'close', 'volume'
# - I checked through the entire columns,
# - I observed no  duplicated rows
# - I oberved null values in 3 columns namely; 'open', 'high', 'low'
# - I filled all columns that has null values with their respective mean values.
# - The 'date' column was already converted from the object type into a datetime type for easy usage
# - I added a new column named 'day' so as for easy analysis

# %% [markdown]
# ## Questions
#
# - Which date in the sample saw the largest overall trading volume? On that date, which two stocks were traded most?
#
# - On which day of the week does volume tend to be highest? Lowest?
#
# - On which date did Amazon (AMZN) see the most volatility, measured by the difference between the high and low price?
#
# - If you could go back in time and invest in one stock from 1/2/2014 - 12/29/2017, which would you choose? What % gain would you realize?

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# - The time frame for this dataset is between, 2nd of January, 2014 to 29th of December, 2017.
# - 24th of August, 2015 saw the highest overall trading volume across the time frame. A sum total of 4,607,945,196 was traded on that day.
# - the two most traded stocks on that day were **BAC** and **AAPL** with a trading volume of 214,649,482 and 162,206,292 respectively
# - Wednesday has the highest trading volume in the weekday(441,712,704,746), closely followed by Friday(440,535,234,884), while Monday has the least(374,346,703,519).
# - No trading activities were observed for Saturdays and Sundays
# - On the 9th of JUne, 2016, Amazon stock(AMZN) witnessed it most volatitlity as diffrence in the high and low price was as much as 85.99
# - Within the timeframe of this dataset, the top 3 best stocks to  invest in are:
#     - NVDA
#     - AVGO
#     - EA
# - The top # worst performing stocks are:
#     - CHK
#     - RRC
#     - DISCA

# %% [markdown]
# ![Screenshot%202023-01-04%20204336.png](attachment:Screenshot%202023-01-04%20204336.png)
